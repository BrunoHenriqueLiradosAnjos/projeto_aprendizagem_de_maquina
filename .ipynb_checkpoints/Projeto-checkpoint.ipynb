# %%
import pandas as pd
import seaborn as sns
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, balanced_accuracy_score, accuracy_score

# %%
df = pd.read_csv("okcupid-stem.csv")
df
# Out:
# C:\Users\bhla\anaconda3\envs\DataScience\lib\site-packages\IPython\core\interactiveshell.py:3172: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        age       body_type               diet      drinks      drugs  \
# 0       22  a little extra  strictly anything    socially      never
# 1       35         average       mostly other       often  sometimes
# 2       23            thin         vegetarian    socially          ?
# 3       29        athletic                  ?    socially      never
# 4       29         average    mostly anything    socially          ?
# ...    ...             ...                ...         ...        ...
# 50784   59               ?                  ?    socially      never
# 50785   24             fit    mostly anything       often  sometimes
# 50786   42         average    mostly anything  not at all      never
# ...

# %%
# As target, the variable 'job' was collapsed into three categories:
#'stem', 'non_stem', and 'student'. STEM jobs were defined as 
#'job' %in% c('computer / hardware / software', 'science / tech / engineering').
sns.countplot(x = df["job"]);

# %% [markdown]
# **Mudando os valores  ? para NaN**

# %%
for i in df.columns:    
    df.loc[df[i] == "?", i] = np.NaN
df
# Out:
#         age       body_type               diet      drinks      drugs  \
# 0      22.0  a little extra  strictly anything    socially      never
# 1      35.0         average       mostly other       often  sometimes
# 2      23.0            thin         vegetarian    socially        NaN
# 3      29.0        athletic                NaN    socially      never
# 4      29.0         average    mostly anything    socially        NaN
# ...     ...             ...                ...         ...        ...
# 50784  59.0             NaN                NaN    socially      never
# 50785  24.0             fit    mostly anything       often  sometimes
# 50786  42.0         average    mostly anything  not at all      never
# 50787  27.0        athletic    mostly anything    socially      often
# 50788  39.0         average                NaN    socially        NaN
#
#                                education            ethnicity height  income  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50789 entries, 0 to 50788
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          50789 non-null  float64
#  1   body_type    46884 non-null  object
#  2   diet         31407 non-null  object
#  3   drinks       49237 non-null  object
#  4   drugs        39167 non-null  object
#  5   education    47303 non-null  object
#  6   ethnicity    46800 non-null  object
#  7   height       50788 non-null  object
#  8   income       10903 non-null  object
#  9   job          50789 non-null  object
#  10  last_online  50789 non-null  object
#  11  location     50789 non-null  object
#  12  offspring    21875 non-null  object
#  13  orientation  50789 non-null  object
#  14  pets         35851 non-null  object
#  15  religion     35663 non-null  object
#  16  sex          50789 non-null  object
#  17  sign         43089 non-null  object
# ...

# %% [markdown]
# **age**

# %%
#Categorizar
df['age_cat'] = pd.cut(pd.to_numeric(df['age']), bins=10)
df['age_cat']
del df['age']

# %% [markdown]
# **'body_type'**

# %%
df['body_type'].value_counts()
# Out:
# average           12583
# fit               10988
# athletic          10183
# thin               3962
# curvy              3392
# a little extra     2308
# skinny             1442
# full figured        888
# overweight          383
# jacked              327
# used up             280
# rather not say      148
# Name: body_type, dtype: int64

# %%
#Descartando os NAN do tipo body_type, ja que não tem uma categoria mais generica
df = df.iloc[df["body_type"].dropna().index]
df.shape
# Out:
# (46884, 21)

# %% [markdown]
# **diet**

# %%
df['diet'].value_counts()
# Out:
# mostly anything        14479
# anything                5145
# strictly anything       4305
# mostly vegetarian       2884
# mostly other             888
# strictly vegetarian      702
# vegetarian               483
# strictly other           378
# other                    274
# mostly vegan             252
# strictly vegan           172
# vegan                    102
# mostly kosher             70
# mostly halal              37
# strictly kosher           15
# strictly halal            13
# kosher                     9
# halal                      6
# Name: diet, dtype: int64

# %%
#Substituindo de NaN pela variavel generica other
df[["diet"]] = df[["diet"]].fillna("other")
df.shape
# Out:
# C:\Users\bhla\anaconda3\envs\DataScience\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# (46884, 21)

# %% [markdown]
# **drinks**

# %%
df['drinks'].value_counts()
# Out:
# socially       33590
# rarely          4791
# often           4034
# not at all      2590
# very often       361
# desperately      237
# Name: drinks, dtype: int64

# %%
df = df.loc[df["drinks"].dropna().index]
df.shape
# Out:
# (45603, 21)

# %% [markdown]
# **drugs**

# %%
df['drugs'].unique()
# Out:
# array(['never', 'sometimes', nan, 'often'], dtype=object)

# %%
df = df.loc[df['drugs'].dropna().index]
df.shape
# Out:
# (35885, 21)

# %% [markdown]
# **education**

# %%
df = df.loc[df['education'].dropna().index]
df.shape
# Out:
# (33624, 21)

# %% [markdown]
# **ethnicity**

# %%
#Deletando para o modelo não levar em conta etnia
#atributo extremamente desorganizado
df['ethnicity'].value_counts()
del df['ethnicity']

# %% [markdown]
# **height**

# %%
#Categorizar
df['height_cat'] = pd.cut(pd.to_numeric(df['height']), bins=10)
df['height_cat']
del df['height']

# %% [markdown]
# **income**

# %%
#Muito valores nulos, mais da metade.
df['income'].isna().sum()
del df['income']

# %% [markdown]
# **last_online**

# %%
#apagando datas
del df['last_online']

# %% [markdown]
# **location**

# %%
#apagando localidades
del df['location']

# %% [markdown]
# **offspring**

# %%
#Atributo ligado a etnia
del df['offspring']

# %% [markdown]
# **orientation**

# %%
del df['orientation']

# %% [markdown]
# **religion**

# %%
del df['religion']

# %% [markdown]
# **sex**

# %%
df['sex'].value_counts(),df['sex'].isna().sum()
# Out:
# (m    20217
#  f    13407
#  Name: sex, dtype: int64,
#  0)

# %% [markdown]
# **sign**

# %%
#Vou deletar, mas se algum de vocÊs quiseram tratar isso e deixar so o signo fiquem avontade
df['sign'].value_counts()
del df['sign']

# %% [markdown]
# **pets**

# %%
df['pets'].value_counts(),df['pets'].isna().sum()
# Out:
# (likes dogs and likes cats          8852
#  likes dogs                         4239
#  likes dogs and has cats            2489
#  has dogs                           2301
#  has dogs and likes cats            1447
#  likes dogs and dislikes cats       1343
#  has dogs and has cats               912
#  has cats                            768
#  likes cats                          590
#  has dogs and dislikes cats          363
#  dislikes dogs and likes cats        182
#  dislikes dogs and dislikes cats     141
#  dislikes cats                        76
#  dislikes dogs and has cats           51
#  dislikes dogs                        31
#  Name: pets, dtype: int64,
#  8866)

# %%
df[["pets"]] = df[["pets"]].fillna("/kickwhatever")
df.shape
# Out:
# (32651, 13)

# %% [markdown]
# **smoke**

# %%
df['smokes'].value_counts(),df['smokes'].isna().sum()
# Out:
# (no                26958
#  sometimes          2031
#  when drinking      1701
#  yes                1158
#  trying to quit      803
#  Name: smokes, dtype: int64,
#  973)

# %%
df = df.loc[df['smokes'].dropna().index]
df.shape
# Out:
# (32651, 13)

# %% [markdown]
# **speaks**

# %%
#Dexei por prequiça.
df['speaks'].value_counts(),df['smokes'].isna().sum()
del df['speaks']

# %%
df['status'].value_counts(),df['smokes'].isna().sum()
# Out:
# (single            30511
#  seeing someone     1023
#  available           949
#  married             165
#  unknown               3
#  Name: status, dtype: int64,
#  0)

# %%
sns.countplot(x = df["job"]);

# %% [markdown]
# **Mudar tipos pra category com one-hot encoding**

# %%
df
# Out:
#             body_type                 diet      drinks      drugs  \
# 0      a little extra    strictly anything    socially      never
# 1             average         mostly other       often  sometimes
# 3            athletic                other    socially      never
# 5             average      mostly anything    socially      never
# 6            athletic      mostly anything  not at all      never
# ...               ...                  ...         ...        ...
# 50778             fit  strictly vegetarian      rarely      never
# 50781         average      mostly anything    socially      never
# 50785             fit      mostly anything       often  sometimes
# 50786         average      mostly anything  not at all      never
# 50787        athletic      mostly anything    socially      often
#
#                                education       job                       pets  \
# 0          working on college/university  non_stem  likes dogs and likes cats
# ...

# %%
i
# Out:
# 'speaks'

# %%
from sklearn.preprocessing import LabelEncoder 
normalized_df = pd.DataFrame()
for i in df:
    
    labelencoder= LabelEncoder()
    normalized_df[i] = pd.to_numeric(labelencoder.fit_transform(df[i]))
normalized_df
# Out:
#        body_type  diet  drinks  drugs  education  job  pets  sex  smokes  \
# 0              0    10       4      0         24    0    15    1       1
# 1              2     6       2      2         30    0    15    1       0
# 2              1     9       4      0          9    0    15    1       0
# 3              2     3       4      0          9    0    15    0       0
# 4              1     3       1      0         31    2    15    1       0
# ...          ...   ...     ...    ...        ...  ...   ...  ...     ...
# 32646          4    15       3      0          9    1    12    1       0
# 32647          2     3       4      0          9    0     0    0       0
# 32648          4     3       2      2         24    0    15    1       0
# 32649          2     3       1      0         12    0     0    1       0
# 32650          1     3       4      1         24    0    15    1       2
#
#        status  age_cat  height_cat
# 0           3        0           5
# ...

# %% [markdown]
# **Normalização entre 0 - 1**

# %%
#normlizando 0 - 1
for i in df.columns:
    if i != "job":
        normalized_df[i]=(normalized_df[i]-normalized_df[i].min())/(normalized_df[i].max()-normalized_df[i].min())
    else:
        normalized_df[i] = normalized_df[i]
        
normalized_df
# Out:
#        body_type      diet  drinks  drugs  education  job  pets  sex  smokes  \
# 0       0.000000  0.588235     0.8    0.0   0.774194    0   1.0  1.0    0.25
# 1       0.181818  0.352941     0.4    1.0   0.967742    0   1.0  1.0    0.00
# 2       0.090909  0.529412     0.8    0.0   0.290323    0   1.0  1.0    0.00
# 3       0.181818  0.176471     0.8    0.0   0.290323    0   1.0  0.0    0.00
# 4       0.090909  0.176471     0.2    0.0   1.000000    2   1.0  1.0    0.00
# ...          ...       ...     ...    ...        ...  ...   ...  ...     ...
# 32646   0.363636  0.882353     0.6    0.0   0.290323    1   0.8  1.0    0.00
# 32647   0.181818  0.176471     0.8    0.0   0.290323    0   0.0  0.0    0.00
# 32648   0.363636  0.176471     0.4    1.0   0.774194    0   1.0  1.0    0.00
# 32649   0.181818  0.176471     0.2    0.0   0.387097    0   0.0  1.0    0.00
# 32650   0.090909  0.176471     0.8    0.5   0.774194    0   1.0  1.0    0.50
#
#        status  age_cat  height_cat
# ...

# %% [markdown]
# **Usar o dataset Categorico no Nayves Bayse**

# %% [markdown]
# **Sem balanceamento e Sem GS**

# %%
def classificador(model,X_train, X_test,y_train, y_test):
    
    results = pd.DataFrame(columns=["ACC","F1"])
    model.fit(X_train, y_train)
    #utilizando acuracia balanceada
    new_row = {"ACC":balanced_accuracy_score(y_test, model.predict(X_test)),"F1":f1_score(y_test, model.predict(X_test), average='weighted') }




    return new_row

# %%
X = df_enc.drop('job', axis=1).values
y = df_enc['job'].values
splits_kfold = 2

# %%
kf = StratifiedKFold(n_splits=splits_kfold)
kf.get_n_splits(X,y)

metrics = ["ACC","F1"]

df_knn = pd.DataFrame(columns=metrics)
df_tree = pd.DataFrame(columns=metrics)
df_mlp = pd.DataFrame(columns=metrics)
df_nb = pd.DataFrame(columns=metrics)
df_reg_log = pd.DataFrame(columns=metrics)



for train_index, test_index in kf.split(X,y):
    
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    

    model = KNeighborsClassifier(n_neighbors=7)
    df_knn =df_knn.append(classificador(model,X_train, X_test,y_train, y_test), ignore_index=True)
    
     
    model = DecisionTreeClassifier()
    df_tree = df_tree.append(classificador(model,X_train, X_test,y_train, y_test), ignore_index=True)
    
    
    
    model = MLPClassifier(hidden_layer_sizes=(64,64,64), 
                    activation='tanh', solver='sgd',
                    alpha=0.0001,
                    learning_rate='adaptive', max_iter=1000)
    df_mlp  = df_mlp.append(classificador(model,X_train, X_test,y_train, y_test), ignore_index=True)
    
    
    
    model = GaussianNB()
    df_nb = df_np.append(classificador(model,X_train, X_test,y_train, y_test), ignore_index=True) 
    
    
    
    model = LogisticRegression(solver='liblinear')
    df_reg_log = df_reg_log.append(classificador(model,X_train, X_test,y_train, y_test), ignore_index=True)

# %%
df_knn
# Out:
#         ACC        F1
# 0  0.460676  0.650383
# 1  0.452334  0.645777

# %%
df_tree
# Out:
#         ACC        F1
# 0  0.463263  0.630526
# 1  0.461548  0.634202

# %%
df_mlp
# Out:
#         ACC        F1
# 0  0.454091  0.638894
# 1  0.457202  0.639776

# %%
df_nb
# Out:
#         ACC        F1
# 0  0.581396  0.655604
# 1  0.597628  0.664316
# 2  0.597628  0.664316

# %%
df_reg_log
# Out:
#         ACC        F1
# 0  0.406477  0.623786
# 1  0.406041  0.624786
